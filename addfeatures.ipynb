# %%
import pandas as pd

# %%
df = pd.read_csv("datasets/DataCoSupplyChainDataset.csv", sep=',',
            encoding="ISO-8859-1" )
df[:5]
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# 1                   1           73  Sporting Goods        Caguas  ...
# 2                   0           73  Sporting Goods      San Jose  ...
# 3                   0           73  Sporting Goods   Los Angeles  ...
# 4                   0           73  Sporting Goods        Caguas  ...
#
#   Order Zipcode Product Card Id Product Category Id  Product Description  \
# 0           NaN            1360                  73                  NaN
# 1           NaN            1360                  73                  NaN
# 2           NaN            1360                  73                  NaN
# 3           NaN            1360                  73                  NaN
# 4           NaN            1360                  73                  NaN
#
#                                   Product Image  Product Name Product Price  \
# 0  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 1  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 2  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 3  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
# 4  http://images.acmesports.sports/Smart+watch   Smart watch         327.75
#
#   Product Status shipping date (DateOrders)   Shipping Mode
# 0              0             2/3/2018 22:56  Standard Class
# 1              0            1/18/2018 12:27  Standard Class
# 2              0            1/17/2018 12:06  Standard Class
# 3              0            1/16/2018 11:45  Standard Class
# 4              0            1/15/2018 11:24  Standard Class
#
# [5 rows x 53 columns]

# %%
df = pd.read_csv("dataset_clean.csv", sep=',',
            encoding="ISO-8859-1")
lend = [1 for l in df['Dest_Lat'] if l != '' ]
len(lend)
# Out:
# 180519

# %%
import math
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # Earth radius in km

    lat1, lon1, lat2, lon2 = map(math.radians, [lat1, lon1, lat2, lon2])

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))

    return R * c
df["distance"] = df.apply(
    lambda row: haversine(
        row["Dest_Lat"],
        row["Dest_Lon"],
        row["Latitude"],
        row["Longitude"]
    ),
    axis=1
)
df.to_csv("dataset_clean_with_dist.csv")
df.head()
# Out:
#    Late_delivery_risk  Days for shipment (scheduled) order date (DateOrders)  \
# 0                   0                              4         1/31/2018 22:56
# 1                   1                              4         1/13/2018 12:27
# 2                   0                              4         1/13/2018 12:06
# 3                   0                              4         1/13/2018 11:45
# 4                   0                              4         1/13/2018 11:24
#
#     Shipping Mode        Market    Order Region   Latitude   Longitude  \
# 0  Standard Class  Pacific Asia  Southeast Asia  18.251453  -66.037056
# 1  Standard Class  Pacific Asia      South Asia  18.279451  -66.037064
# 2  Standard Class  Pacific Asia      South Asia  37.292233 -121.881279
# 3  Standard Class  Pacific Asia         Oceania  34.125946 -118.291016
# 4  Standard Class  Pacific Asia         Oceania  18.253769  -66.037048
#
#     Category Name Department Name  ...  Product Status  Customer Segment  \
# 0  Sporting Goods         Fitness  ...               0          Consumer
# 1  Sporting Goods         Fitness  ...               0          Consumer
# 2  Sporting Goods         Fitness  ...               0          Consumer
# 3  Sporting Goods         Fitness  ...               0       Home Office
# 4  Sporting Goods         Fitness  ...               0         Corporate
#
#   Order Item Total  Order Profit Per Order  Order Item Discount Rate  \
# 0       314.640015               91.250000                      0.04
# 1       311.359985             -249.089996                      0.05
# 2       309.720001             -247.779999                      0.06
# 3       304.809998               22.860001                      0.07
# 4       298.250000              134.210007                      0.09
#
#    Order City      Order State   Dest_Lat    Dest_Lon      distance
# 0      Bekasi  Java Occidental  -6.234986  106.994544  18480.058856
# 1     Bikaner        RajastÃ¡n  28.015929   73.317137  13260.637223
# 2     Bikaner        RajastÃ¡n  28.015929   73.317137  12581.935467
# 3  Townsville       Queensland -19.256939  146.823954  11627.729706
# 4  Townsville       Queensland -19.256939  146.823954  16558.444661
#
# [5 rows x 21 columns]
